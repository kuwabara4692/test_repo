# %%
import pandas as pd

# %%
df=pd.read_csv('..\cama\Export_Output.csv')
df
# Out:
# C:\Users\ckohler\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (1,10,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          OBJECTID         PIN                                         LAST  \
# 0      21134094.0  0625400001                                       BLUNDY
# 1      21135177.0  0630100003                                       ROFFEY
# 2      21130300.0  1304200002                      AMEREN ILLINOIS COMPANY
# 3      21126964.0  1112100002                                      WINDISH
# 4      21069851.0  1727200004     METROPOLITAN AIRPORT AUTHORITY OF PEORIA
# 5      21061774.0  1727100005                          EXPORT PACKAGING CO
# 6      21068103.0  1530300004                          CLYDE R MORBY TRUST
# 7      21067376.0  1731103009          CAMELOT ROUND TABLE ASSOCIATION INC
# ...

# %%
list(df)
# Out:
# ['OBJECTID',
#  'PIN',
#  'LAST',
#  'FIRST',
#  'MI_',
#  'SUFIX',
#  'ADDR1',
#  'ADDR2',
#  'OWNCTY',
#  'OWNSTE',
#  'OWZIP',
#  'CITY',
#  'STATE',
#  'PZIP',
#  'TAX_',
#  'owner_name',
#  'HOUSE_',
#  'DIR',
#  'STREET',
#  'HSESFX',
#  'land_lot_v',
#  'improvemen',
#  'total_asse',
#  'neighborhood',
#  'class_char',
#  'total_living',
#  'bsmnt_finished_',
#  'bsmnt_area',
#  'rec_area',
#  'detached_gar_ar',
#  'garage_area',
#  'fireplaces',
#  'central_air',
#  'n_bedrooms',
#  'main_living',
#  'full_baths',
#  'half_baths',
#  'year_built',
#  'eff_year_built',
#  'PropClass',
#  'cdu',
#  'gradeDesc',
#  'exterior_cover_',
#  'mkt_house_',
#  'story_conf',
#  'COMBADD',
#  'grade',
#  'ValPerSqft',
#  'story_co_1',
#  'mkt_house1',
#  'ext_cover1',
#  'LEGAL',
#  'non_farm_a',
#  'farm_build',
#  'farm_lot_v',
#  'property_street',
#  'Acres']

# %%
df.loc[:, 'ADDR1'].value_counts()
# Out:
# P O BOX 96                              664
# 419 FULTON ST                           552
# ATTN EXECUTIVE OFFICE                   392
# P O BOX 9565                            364
# NOBLE ADMINISTRATION CENTER             321
# 6100 W EVERETT MCKINLEY DIRKSEN PKWY    270
# P O BOX 66149 MC 210                    260
# 3622 N KNOXVILLE AVE                    254
# PROPERTY TAX DEPARTMENT                 239
# 1501 W BRADLEY AVE                      219
# ONE NATURAL RESOURCES WAY               183
# P O BOX 2500                            176
# 4120 BELMONT POINT                      170
# C/O PCCEO                               146
# 7219 N VAUXHALL PL                       92
# 419 FULTON ST ROOM 307                   91
# ATTN MARC REINOEHL                       82
# 5001 N UNIVERSITY ST                     78
# 200 MERIDIAN CENTRE BLVD STE 300         74
# 221 NE GLEN OAK AVE                      74
# 6403 N TALISMAN TERRACE                  70
# ...

# %%
df.loc[:, 'PIN'].value_counts()
# Out:
# 1611178001    41
# 624400011     36
# 1432204001    27
# 1809233012    20
# 1430201004    20
# 1434304039    18
# 1810102003    16
# 1434304039    16
# 1804434021    16
# 1336400004    14
# 1711276003    14
# 1007327015    13
# 1410378011    12
# 1809201001    12
# 1806101004    12
# 0716400002    12
# 1410378008    11
# 1410378008    10
# 1320300012    10
# 509400007     10
# 1410378012    10
# 1721400012     9
# 1710251001     9
# 932151005      9
# 1721400004     9
# 1419326024     9
# 1406226029     8
# 1809255011     8
# 1405278009     8
# 923100004      8
#               ..
# 1323128010     1
# 1323128011     1
# 1323128012     1
# 1323128013     1
# 1108301006     1
# 1108301007     1
# 1108301008     1
# 1108301009     1
# 1419279018     1
# 0919454017     1
# 0932478007     1
# 1314429029     1
# 0826100003     1
# 0418155011     1
# 1428377060     1
# 1710426012     1
# 1430182018     1
# 1630100004     1
# 1435302047     1
# 1325451006     1
# 1818104016     1
# ...
